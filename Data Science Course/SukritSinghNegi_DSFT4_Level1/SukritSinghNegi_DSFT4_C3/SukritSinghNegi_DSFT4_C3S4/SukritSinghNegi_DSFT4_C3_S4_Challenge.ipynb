# %%
print('Welcome to the Quiz')
print('Answer alphabet of option ')
score=0
# Question 1
print('1)what is 1+2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_1="c"
answer=input('answer:')
if(answer.lower()==answer_1):
    score=score+1

# Question 2
print('2)what is 2+2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_2="d"
answer=input('answer:')
if(answer.lower()==answer_2):
    score=score+1
    
# Question 3
print('3)what is 2*2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_3="d"
answer=input('answer:')
if(answer.lower()==answer_3):
    score=score+1
        
# Question 4
print('4)what is 4/2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_4="b"
answer=input('answer:')
if(answer.lower()==answer_4):
    score=score+1  
    
# Question 5
print('5)what is 3%2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_5="a"
answer=input('answer:')
if(answer.lower()==answer_5):
    score=score+1  

# Question 6
print('6)what is 2**2=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_6="d"
answer=input('answer:')
if(answer.lower()==answer_6):
    score=score+1 
    
# Question 7
print('7)what is 3/3=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_7="a"
answer=input('answer:')
if(answer.lower()==answer_7):
    score=score+1   

    
# Question 8
print('8)what is 3+1=?\n(a)1\n(b)2\n(c)3\n(d)4')
answer_8="d"
answer=input('answer:')
if(answer.lower()==answer_8):
    score=score+1  
    
    
# Question 9
print('9)what is 3*0=?\n(a)1\n(b)2\n(c)3\n(d)0')
answer_9="d"
answer=input('answer:')
if(answer.lower()==answer_9):
    score=score+1
    
    
# Question 10
print('10)what is 1//2=?\n(a)1\n(b)2\n(c)3\n(d)0')
answer_10="d"
answer=input('answer:')
if(answer.lower()==answer_10):
    score=score+1
   
   
print('your score is : ' ,score)
print(' 1',answer_1,'\n','2',answer_2,'\n','3',answer_3,'\n','4',answer_4,'\n','5',answer_5,'\n','6',answer_6,'\n','7',answer_7,'\n','8',answer_8,'\n','9',answer_9,'\n','10',answer_10)
# Out:
# Welcome to the Quiz
# Answer alphabet of option
# 1)what is 1+2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 2)what is 2+2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 3)what is 2*2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 4)what is 4/2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 5)what is 3%2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 6)what is 2**2=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 7)what is 3/3=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 8)what is 3+1=?
# (a)1
# (b)2
# (c)3
# (d)4
# answer:a
# 9)what is 3*0=?
# (a)1
# (b)2
# (c)3
# (d)0
# answer:a
# 10)what is 1//2=?
# (a)1
# (b)2
# (c)3
# (d)0
# answer:a
# your score is :  2
#  1 c
#  2 d
#  3 d
#  4 b
#  5 a
#  6 d
#  7 a
#  8 d
#  9 d
#  10 d
