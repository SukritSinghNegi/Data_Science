# %% [markdown]
# # ETL Operations Using Python

# %%
import mysql.connector as sql
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('housing.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
a1=df[(df.LotArea>6000)&(df.LotConfig=='Corner')]
print(a1.shape)
print(a1)
# Out:
# (238, 81)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1413  1414          20       RL         88.0    10994   Pave   NaN      IR1
# 1420  1421          60       RL         90.0    11700   Pave   NaN      Reg
# 1428  1429          30       RM         60.0     7200   Pave   NaN      Reg
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
#
# ...

# %%
# Task 2
b=df[(df.BldgType=='1Fam')&(df.HouseStyle=='1Story')&(df.LandContour=='Lvl')]
print(b.shape)
print(b)
# Out:
# (545, 81)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Task 3
c=df[df.LotArea==df.LotArea.min()]
c
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956  957         160       RM         24.0     1300   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 956         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 956      5   2009        WD         Normal     124000
#
# [1 rows x 81 columns]

# %%
c1=df.sort_values(['LotArea']).head(10)
c2=c1.sort_values(['SalePrice'],ascending=False)
c2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 225    226         160       RM         21.0     1680   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# 232    233         160       RM         21.0     1680   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 235    236         160       RM         21.0     1680   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
# Task 4
d=df[(df.BedroomAbvGr>3)&(df.BsmtFullBath==1)&(df.Exterior1st=='CemntBd')]
d
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 316    317          60       RL         94.0    13005   Pave   NaN      IR1
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 1068  1069         160       RM         42.0     3964   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 316          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 349          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 1068         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 316       8   2009        WD         Normal     260000
# 349       4   2006       New        Partial     437154
# ...

# %%
# Task 5
e=df[(df.GarageCars==2)&(df.GarageType=='Attchd')&(df.GarageArea>=500)]
e
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
# ...

# %%
db=sql.connect(host='localhost',user='root',password='Sukrit_1996')
f=db.cursor()
f.execute('create database housing')

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='housing',user='root',pw='Sukrit_1996'))
a1.to_sql('Corner_Area>6000',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Corner_Area>6000' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='housing',user='root',pw='Sukrit_1996'))
b.to_sql('1Fam1StryLvl',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name '1Fam1StryLvl' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='housing',user='root',pw='Sukrit_1996'))
c.to_sql('compacthousing',engine,index=False)

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='housing',user='root',pw='Sukrit_1996'))
d.to_sql('BdrmBsmntCnrt',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'BdrmBsmntCnrt' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='housing',user='root',pw='Sukrit_1996'))
e.to_sql('2CarGarage',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name '2CarGarage' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
