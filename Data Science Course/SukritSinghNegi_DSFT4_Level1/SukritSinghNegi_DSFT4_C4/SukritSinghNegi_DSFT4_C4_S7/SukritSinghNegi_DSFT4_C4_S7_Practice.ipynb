# %% [markdown]
# # ETL Operations Using Python

# %%
# !pip install pymysql
import mysql.connector as sql
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pymysql in c:\users\krish\anaconda3\lib\site-packages (1.0.2)

# %%
# Task 1
db=sql.connect(host='localhost',user='root',password='Sukrit_1996',database='hr')
a=db.cursor()

# %%
q='show tables'
a.execute(q)
for i in a:
    print(i)
# Out:
# ('countries',)
# ('departments',)
# ('emp_details_view',)
# ('employees',)
# ('job_history',)
# ('jobs',)
# ('locations',)
# ('regions',)

# %%
q1='describe employees'
a.execute(q1)
for i in a:
    print(i)
# Out:
# ('employee_id', b'int unsigned', 'NO', 'PRI', None, '')
# ('first_name', b'varchar(20)', 'YES', '', None, '')
# ('last_name', b'varchar(25)', 'NO', '', None, '')
# ('email', b'varchar(25)', 'NO', '', None, '')
# ('phone_number', b'varchar(20)', 'YES', '', None, '')
# ('hire_date', b'date', 'NO', '', None, '')
# ('job_id', b'varchar(10)', 'NO', 'MUL', None, '')
# ('salary', b'decimal(8,2)', 'NO', '', None, '')
# ('commission_pct', b'decimal(2,2)', 'YES', '', None, '')
# ('manager_id', b'int unsigned', 'YES', 'MUL', None, '')
# ('department_id', b'int unsigned', 'YES', 'MUL', None, '')
# ('annual_CTC', b'int', 'NO', '', None, '')

# %%
q2='describe countries'
a.execute(q2)
for i in a:
    print(i)
# Out:
# ('country_id', b'char(2)', 'NO', 'PRI', None, '')
# ('country_name', b'varchar(40)', 'YES', '', None, '')
# ('region_id', b'int unsigned', 'NO', 'MUL', None, '')

# %%
q3='describe locations'
a.execute(q3)
for i in a:
    print(i)
# Out:
# ('location_id', b'int unsigned', 'NO', 'PRI', None, 'auto_increment')
# ('street_address', b'varchar(40)', 'YES', '', None, '')
# ('postal_code', b'varchar(12)', 'YES', '', None, '')
# ('city', b'varchar(30)', 'NO', '', None, '')
# ('state_province', b'varchar(25)', 'YES', '', None, '')
# ('country_id', b'char(2)', 'NO', 'MUL', None, '')

# %%
q4='describe departments'
a.execute(q4)
for i in a:
    print(i)
# Out:
# ('department_id', b'int unsigned', 'NO', 'PRI', None, '')
# ('department_name', b'varchar(30)', 'NO', '', None, '')
# ('manager_id', b'int unsigned', 'YES', 'MUL', None, '')
# ('location_id', b'int unsigned', 'YES', 'MUL', None, '')

# %%
q5='select * from employees e left join departments d on e.department_id=d.department_id left join locations l on d.location_id=l.location_id left join countries c on l.country_id=c.country_id'
a.execute(q5)
d=a.fetchall()
for i in d:
    print(i)
# Out:
# (100, 'Steven', 'King', 'SKING', '515.123.4567', datetime.date(1987, 6, 17), 'AD_PRES', Decimal('25200.00'), None, None, 90, 302400, 90, 'Executive', 100, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', datetime.date(1989, 9, 21), 'AD_VP', Decimal('18700.00'), None, 100, 90, 224400, 90, 'Executive', 100, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', datetime.date(1993, 1, 13), 'AD_VP', Decimal('18700.00'), None, 100, 90, 224400, 90, 'Executive', 100, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', datetime.date(1990, 1, 3), 'IT_PROG', Decimal('11880.00'), None, 102, 60, 142560, 60, 'IT', 103, 1400, 1400, '2014 Jabberwocky Rd', '26192', 'Southlake', 'Texas', 'US', 'US', 'United States of America', 2)
# (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', datetime.date(1991, 5, 21), 'IT_PROG', Decimal('7200.00'), None, 103, 60, 86400, 60, 'IT', 103, 1400, 1400, '2014 Jabberwocky Rd', '26192', 'Southlake', 'Texas', 'US', 'US', 'United States of America', 2)
# (105, 'David', 'Austin', 'DAUSTIN', '590.423.4569', datetime.date(1997, 6, 25), 'IT_PROG', Decimal('5760.00'), None, 103, 60, 69120, 60, 'IT', 103, 1400, 1400, '2014 Jabberwocky Rd', '26192', 'Southlake', 'Texas', 'US', 'US', 'United States of America', 2)
# (106, 'Valli', 'Pataballa', 'VPATABAL', '590.423.4560', datetime.date(1998, 2, 5), 'IT_PROG', Decimal('5760.00'), None, 103, 60, 69120, 60, 'IT', 103, 1400, 1400, '2014 Jabberwocky Rd', '26192', 'Southlake', 'Texas', 'US', 'US', 'United States of America', 2)
# (107, 'Diana', 'Lorentz', 'DLORENTZ', '590.423.5567', datetime.date(1999, 2, 7), 'IT_PROG', Decimal('5040.00'), None, 103, 60, 60480, 60, 'IT', 103, 1400, 1400, '2014 Jabberwocky Rd', '26192', 'Southlake', 'Texas', 'US', 'US', 'United States of America', 2)
# (108, 'Nancy', 'Greenberg', 'NGREENBE', '515.124.4569', datetime.date(1994, 8, 17), 'FI_MGR', Decimal('15840.00'), None, 101, 100, 190080, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (109, 'Daniel', 'Faviet', 'DFAVIET', '515.124.4169', datetime.date(1994, 8, 16), 'FI_ACCOUNT', Decimal('11880.00'), None, 108, 100, 142560, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (110, 'John', 'Chen', 'JCHEN', '515.124.4269', datetime.date(1997, 9, 28), 'FI_ACCOUNT', Decimal('9840.00'), None, 108, 100, 118080, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (111, 'Ismael', 'Sciarra', 'ISCIARRA', '515.124.4369', datetime.date(1997, 9, 30), 'FI_ACCOUNT', Decimal('9240.00'), None, 108, 100, 110880, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (112, 'Jose Manuel', 'Urman', 'JMURMAN', '515.124.4469', datetime.date(1998, 3, 7), 'FI_ACCOUNT', Decimal('9360.00'), None, 108, 100, 112320, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (113, 'Luis', 'Popp', 'LPOPP', '515.124.4567', datetime.date(1999, 12, 7), 'FI_ACCOUNT', Decimal('8280.00'), None, 108, 100, 99360, 100, 'Finance', 108, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (114, 'Den', 'Raphaely', 'DRAPHEAL', '515.127.4561', datetime.date(1994, 12, 7), 'PU_MAN', Decimal('14520.00'), None, 100, 30, 174240, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (115, 'Alexander', 'Khoo', 'AKHOO', '515.127.4562', datetime.date(1995, 5, 18), 'PU_CLERK', Decimal('3720.00'), None, 114, 30, 44640, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (116, 'Shelli', 'Baida', 'SBAIDA', '515.127.4563', datetime.date(1997, 12, 24), 'PU_CLERK', Decimal('3480.00'), None, 114, 30, 41760, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (117, 'Sigal', 'Tobias', 'STOBIAS', '515.127.4564', datetime.date(1997, 7, 24), 'PU_CLERK', Decimal('3360.00'), None, 114, 30, 40320, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (118, 'Guy', 'Himuro', 'GHIMURO', '515.127.4565', datetime.date(1998, 11, 15), 'PU_CLERK', Decimal('3120.00'), None, 114, 30, 37440, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (119, 'Karen', 'Colmenares', 'KCOLMENA', '515.127.4566', datetime.date(1999, 8, 10), 'PU_CLERK', Decimal('3000.00'), None, 114, 30, 36000, 30, 'Purchasing', 114, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (120, 'Matthew', 'Weiss', 'MWEISS', '650.123.1234', datetime.date(1996, 7, 18), 'ST_MAN', Decimal('9600.00'), None, 100, 50, 115200, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (121, 'Adam', 'Fripp', 'AFRIPP', '650.123.2234', datetime.date(1997, 4, 10), 'ST_MAN', Decimal('9840.00'), None, 100, 50, 118080, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (122, 'Payam', 'Kaufling', 'PKAUFLIN', '650.123.3234', datetime.date(1995, 5, 1), 'ST_MAN', Decimal('9480.00'), None, 100, 50, 113760, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (123, 'Shanta', 'Vollman', 'SVOLLMAN', '650.123.4234', datetime.date(1997, 10, 10), 'ST_MAN', Decimal('7800.00'), None, 100, 50, 93600, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (124, 'Kevin', 'Mourgos', 'KMOURGOS', '650.123.5234', datetime.date(1999, 11, 16), 'ST_MAN', Decimal('6960.00'), None, 100, 50, 83520, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (125, 'Julia', 'Nayer', 'JNAYER', '650.124.1214', datetime.date(1997, 7, 16), 'ST_CLERK', Decimal('3840.00'), None, 120, 50, 46080, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (126, 'Irene', 'Mikkilineni', 'IMIKKILI', '650.124.1224', datetime.date(1998, 9, 28), 'ST_CLERK', Decimal('3240.00'), None, 120, 50, 38880, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (127, 'James', 'Landry', 'JLANDRY', '650.124.1334', datetime.date(1999, 1, 14), 'ST_CLERK', Decimal('2880.00'), None, 120, 50, 34560, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (128, 'Steven', 'Markle', 'SMARKLE', '650.124.1434', datetime.date(2000, 3, 8), 'ST_CLERK', Decimal('2640.00'), None, 120, 50, 31680, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (129, 'Laura', 'Bissot', 'LBISSOT', '650.124.5234', datetime.date(1997, 8, 20), 'ST_CLERK', Decimal('3960.00'), None, 121, 50, 47520, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (130, 'Mozhe', 'Atkinson', 'MATKINSO', '650.124.6234', datetime.date(1997, 10, 30), 'ST_CLERK', Decimal('3360.00'), None, 121, 50, 40320, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (131, 'James', 'Marlow', 'JAMRLOW', '650.124.7234', datetime.date(1997, 2, 16), 'ST_CLERK', Decimal('3000.00'), None, 121, 50, 36000, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (132, 'TJ', 'Olson', 'TJOLSON', '650.124.8234', datetime.date(1999, 4, 10), 'ST_CLERK', Decimal('2520.00'), None, 121, 50, 30240, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (133, 'Jason', 'Mallin', 'JMALLIN', '650.127.1934', datetime.date(1996, 6, 14), 'ST_CLERK', Decimal('3960.00'), None, 122, 50, 47520, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (134, 'Michael', 'Rogers', 'MROGERS', '650.127.1834', datetime.date(1998, 8, 26), 'ST_CLERK', Decimal('3480.00'), None, 122, 50, 41760, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (135, 'Ki', 'Gee', 'KGEE', '650.127.1734', datetime.date(1999, 12, 12), 'ST_CLERK', Decimal('2880.00'), None, 122, 50, 34560, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (136, 'Hazel', 'Philtanker', 'HPHILTAN', '650.127.1634', datetime.date(2000, 2, 6), 'ST_CLERK', Decimal('2640.00'), None, 122, 50, 31680, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (137, 'Renske', 'Ladwig', 'RLADWIG', '650.121.1234', datetime.date(1995, 7, 14), 'ST_CLERK', Decimal('4320.00'), None, 123, 50, 51840, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (138, 'Stephen', 'Stiles', 'SSTILES', '650.121.2034', datetime.date(1997, 10, 26), 'ST_CLERK', Decimal('3840.00'), None, 123, 50, 46080, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (139, 'John', 'Seo', 'JSEO', '650.121.2019', datetime.date(1998, 2, 12), 'ST_CLERK', Decimal('3240.00'), None, 123, 50, 38880, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (140, 'Joshua', 'Patel', 'JPATEL', '650.121.1834', datetime.date(1998, 4, 6), 'ST_CLERK', Decimal('3000.00'), None, 123, 50, 36000, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (141, 'Trenna', 'Rajs', 'TRAJS', '650.121.8009', datetime.date(1995, 10, 17), 'ST_CLERK', Decimal('4200.00'), None, 124, 50, 50400, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (142, 'Curtis', 'Davies', 'CDAVIES', '650.121.2994', datetime.date(1997, 1, 29), 'ST_CLERK', Decimal('3720.00'), None, 124, 50, 44640, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (143, 'Randall', 'Matos', 'RMATOS', '650.121.2874', datetime.date(1998, 3, 15), 'ST_CLERK', Decimal('3120.00'), None, 124, 50, 37440, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (144, 'Peter', 'Vargas', 'PVARGAS', '650.121.2004', datetime.date(1998, 7, 9), 'ST_CLERK', Decimal('3000.00'), None, 124, 50, 36000, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (145, 'John', 'Russell', 'JRUSSEL', '011.44.1344.429268', datetime.date(1996, 10, 1), 'SA_MAN', Decimal('18480.00'), Decimal('0.40'), 100, 80, 221760, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (146, 'Karen', 'Partners', 'KPARTNER', '011.44.1344.467268', datetime.date(1997, 1, 5), 'SA_MAN', Decimal('17820.00'), Decimal('0.30'), 100, 80, 213840, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (147, 'Alberto', 'Errazuriz', 'AERRAZUR', '011.44.1344.429278', datetime.date(1997, 3, 10), 'SA_MAN', Decimal('15840.00'), Decimal('0.30'), 100, 80, 190080, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (148, 'Gerald', 'Cambrault', 'GCAMBRAU', '011.44.1344.619268', datetime.date(1999, 10, 15), 'SA_MAN', Decimal('14520.00'), Decimal('0.30'), 100, 80, 174240, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (149, 'Eleni', 'Zlotkey', 'EZLOTKEY', '011.44.1344.429018', datetime.date(2000, 1, 29), 'SA_MAN', Decimal('13860.00'), Decimal('0.20'), 100, 80, 166320, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (150, 'Peter', 'Tucker', 'PTUCKER', '011.44.1344.129268', datetime.date(1997, 1, 30), 'SA_REP', Decimal('13200.00'), Decimal('0.30'), 145, 80, 158400, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (151, 'David', 'Bernstein', 'DBERNSTE', '011.44.1344.345268', datetime.date(1997, 3, 24), 'SA_REP', Decimal('12540.00'), Decimal('0.25'), 145, 80, 150480, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (152, 'Peter', 'Hall', 'PHALL', '011.44.1344.478968', datetime.date(1997, 8, 20), 'SA_REP', Decimal('11880.00'), Decimal('0.25'), 145, 80, 142560, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (153, 'Christopher', 'Olsen', 'COLSEN', '011.44.1344.498718', datetime.date(1998, 3, 30), 'SA_REP', Decimal('9600.00'), Decimal('0.20'), 145, 80, 115200, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (154, 'Nanette', 'Cambrault', 'NCAMBRAU', '011.44.1344.987668', datetime.date(1998, 12, 9), 'SA_REP', Decimal('9000.00'), Decimal('0.20'), 145, 80, 108000, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (155, 'Oliver', 'Tuvault', 'OTUVAULT', '011.44.1344.486508', datetime.date(1999, 11, 23), 'SA_REP', Decimal('8400.00'), Decimal('0.15'), 145, 80, 100800, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (156, 'Janette', 'King', 'JKING', '011.44.1345.429268', datetime.date(1996, 1, 30), 'SA_REP', Decimal('13200.00'), Decimal('0.35'), 146, 80, 158400, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (157, 'Patrick', 'Sully', 'PSULLY', '011.44.1345.929268', datetime.date(1996, 3, 4), 'SA_REP', Decimal('12540.00'), Decimal('0.35'), 146, 80, 150480, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (158, 'Allan', 'McEwen', 'AMCEWEN', '011.44.1345.829268', datetime.date(1996, 8, 1), 'SA_REP', Decimal('11880.00'), Decimal('0.35'), 146, 80, 142560, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (159, 'Lindsey', 'Smith', 'LSMITH', '011.44.1345.729268', datetime.date(1997, 3, 10), 'SA_REP', Decimal('9600.00'), Decimal('0.30'), 146, 80, 115200, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (160, 'Louise', 'Doran', 'LDORAN', '011.44.1345.629268', datetime.date(1997, 12, 15), 'SA_REP', Decimal('9000.00'), Decimal('0.30'), 146, 80, 108000, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (161, 'Sarath', 'Sewall', 'SSEWALL', '011.44.1345.529268', datetime.date(1998, 11, 3), 'SA_REP', Decimal('8400.00'), Decimal('0.25'), 146, 80, 100800, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (162, 'Clara', 'Vishney', 'CVISHNEY', '011.44.1346.129268', datetime.date(1997, 11, 11), 'SA_REP', Decimal('13860.00'), Decimal('0.25'), 147, 80, 166320, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (163, 'Danielle', 'Greene', 'DGREENE', '011.44.1346.229268', datetime.date(1999, 3, 19), 'SA_REP', Decimal('12540.00'), Decimal('0.15'), 147, 80, 150480, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (164, 'Mattea', 'Marvins', 'MMARVINS', '011.44.1346.329268', datetime.date(2000, 1, 24), 'SA_REP', Decimal('8640.00'), Decimal('0.10'), 147, 80, 103680, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (165, 'David', 'Lee', 'DLEE', '011.44.1346.529268', datetime.date(2000, 2, 23), 'SA_REP', Decimal('8160.00'), Decimal('0.10'), 147, 80, 97920, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (166, 'Sundar', 'Ande', 'SANDE', '011.44.1346.629268', datetime.date(2000, 3, 24), 'SA_REP', Decimal('7680.00'), Decimal('0.10'), 147, 80, 92160, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (167, 'Amit', 'Banda', 'ABANDA', '011.44.1346.729268', datetime.date(2000, 4, 21), 'SA_REP', Decimal('7440.00'), Decimal('0.10'), 147, 80, 89280, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (168, 'Lisa', 'Ozer', 'LOZER', '011.44.1343.929268', datetime.date(1997, 3, 11), 'SA_REP', Decimal('15180.00'), Decimal('0.25'), 148, 80, 182160, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (169, 'Harrison', 'Bloom', 'HBLOOM', '011.44.1343.829268', datetime.date(1998, 3, 23), 'SA_REP', Decimal('13200.00'), Decimal('0.20'), 148, 80, 158400, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (170, 'Tayler', 'Fox', 'TFOX', '011.44.1343.729268', datetime.date(1998, 1, 24), 'SA_REP', Decimal('12672.00'), Decimal('0.20'), 148, 80, 152064, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (171, 'William', 'Smith', 'WSMITH', '011.44.1343.629268', datetime.date(1999, 2, 23), 'SA_REP', Decimal('8880.00'), Decimal('0.15'), 148, 80, 106560, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (172, 'Elizabeth', 'Bates', 'EBATES', '011.44.1343.529268', datetime.date(1999, 3, 24), 'SA_REP', Decimal('8760.00'), Decimal('0.15'), 148, 80, 105120, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (173, 'Sundita', 'Kumar', 'SKUMAR', '011.44.1343.329268', datetime.date(2000, 4, 21), 'SA_REP', Decimal('7320.00'), Decimal('0.10'), 148, 80, 87840, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (174, 'Ellen', 'Abel', 'EABEL', '011.44.1644.429267', datetime.date(1996, 5, 11), 'SA_REP', Decimal('14520.00'), Decimal('0.30'), 149, 80, 174240, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (175, 'Alyssa', 'Hutton', 'AHUTTON', '011.44.1644.429266', datetime.date(1997, 3, 19), 'SA_REP', Decimal('11616.00'), Decimal('0.25'), 149, 80, 139392, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (176, 'Jonathon', 'Taylor', 'JTAYLOR', '011.44.1644.429265', datetime.date(1998, 3, 24), 'SA_REP', Decimal('11352.00'), Decimal('0.20'), 149, 80, 136224, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (177, 'Jack', 'Livingston', 'JLIVINGS', '011.44.1644.429264', datetime.date(1998, 4, 23), 'SA_REP', Decimal('11088.00'), Decimal('0.20'), 149, 80, 133056, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (178, 'Kimberely', 'Grant', 'KGRANT', '011.44.1644.429263', datetime.date(1999, 5, 24), 'SA_REP', Decimal('8400.00'), Decimal('0.15'), 149, None, 100800, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (179, 'Charles', 'Johnson', 'CJOHNSON', '011.44.1644.429262', datetime.date(2000, 1, 4), 'SA_REP', Decimal('7440.00'), Decimal('0.10'), 149, 80, 89280, 80, 'Sales', 145, 2500, 2500, 'Magdalen Centre, The Oxford Science Park', 'OX9 9ZB', 'Oxford', 'Oxford', 'UK', 'UK', 'United Kingdom', 1)
# (180, 'Winston', 'Taylor', 'WTAYLOR', '650.507.9876', datetime.date(1998, 1, 24), 'SH_CLERK', Decimal('3840.00'), None, 120, 50, 46080, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (181, 'Jean', 'Fleaur', 'JFLEAUR', '650.507.9877', datetime.date(1998, 2, 23), 'SH_CLERK', Decimal('3720.00'), None, 120, 50, 44640, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (182, 'Martha', 'Sullivan', 'MSULLIVA', '650.507.9878', datetime.date(1999, 6, 21), 'SH_CLERK', Decimal('3000.00'), None, 120, 50, 36000, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (183, 'Girard', 'Geoni', 'GGEONI', '650.507.9879', datetime.date(2000, 2, 3), 'SH_CLERK', Decimal('3360.00'), None, 120, 50, 40320, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (184, 'Nandita', 'Sarchand', 'NSARCHAN', '650.509.1876', datetime.date(1996, 1, 27), 'SH_CLERK', Decimal('5040.00'), None, 121, 50, 60480, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (185, 'Alexis', 'Bull', 'ABULL', '650.509.2876', datetime.date(1997, 2, 20), 'SH_CLERK', Decimal('4920.00'), None, 121, 50, 59040, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (186, 'Julia', 'Dellinger', 'JDELLING', '650.509.3876', datetime.date(1998, 6, 24), 'SH_CLERK', Decimal('4080.00'), None, 121, 50, 48960, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (187, 'Anthony', 'Cabrio', 'ACABRIO', '650.509.4876', datetime.date(1999, 2, 7), 'SH_CLERK', Decimal('3600.00'), None, 121, 50, 43200, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (188, 'Kelly', 'Chung', 'KCHUNG', '650.505.1876', datetime.date(1997, 6, 14), 'SH_CLERK', Decimal('4560.00'), None, 122, 50, 54720, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (189, 'Jennifer', 'Dilly', 'JDILLY', '650.505.2876', datetime.date(1997, 8, 13), 'SH_CLERK', Decimal('4320.00'), None, 122, 50, 51840, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (190, 'Timothy', 'Gates', 'TGATES', '650.505.3876', datetime.date(1998, 7, 11), 'SH_CLERK', Decimal('3480.00'), None, 122, 50, 41760, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (191, 'Randall', 'Perkins', 'RPERKINS', '650.505.4876', datetime.date(1999, 12, 19), 'SH_CLERK', Decimal('3000.00'), None, 122, 50, 36000, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (192, 'Sarah', 'Bell', 'SBELL', '650.501.1876', datetime.date(1996, 2, 4), 'SH_CLERK', Decimal('4800.00'), None, 123, 50, 57600, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (193, 'Britney', 'Everett', 'BEVERETT', '650.501.2876', datetime.date(1997, 3, 3), 'SH_CLERK', Decimal('4680.00'), None, 123, 50, 56160, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (194, 'Samuel', 'McCain', 'SMCCAIN', '650.501.3876', datetime.date(1998, 7, 1), 'SH_CLERK', Decimal('3840.00'), None, 123, 50, 46080, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (195, 'Vance', 'Jones', 'VJONES', '650.501.4876', datetime.date(1999, 3, 17), 'SH_CLERK', Decimal('3360.00'), None, 123, 50, 40320, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (196, 'Alana', 'Walsh', 'AWALSH', '650.507.9811', datetime.date(1998, 4, 24), 'SH_CLERK', Decimal('3720.00'), None, 124, 50, 44640, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (197, 'Kevin', 'Feeney', 'KFEENEY', '650.507.9822', datetime.date(1998, 5, 23), 'SH_CLERK', Decimal('3600.00'), None, 124, 50, 43200, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (198, 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833', datetime.date(1999, 6, 21), 'SH_CLERK', Decimal('3120.00'), None, 124, 50, 37440, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (199, 'Douglas', 'Grant', 'DGRANT', '650.507.9844', datetime.date(2000, 1, 13), 'SH_CLERK', Decimal('3120.00'), None, 124, 50, 37440, 50, 'Shipping', 121, 1500, 1500, '2011 Interiors Blvd', '99236', 'South San Francisco', 'California', 'US', 'US', 'United States of America', 2)
# (200, 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444', datetime.date(1987, 9, 17), 'AD_ASST', Decimal('5280.00'), None, 101, 10, 63360, 10, 'Administration', 200, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (201, 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555', datetime.date(1996, 2, 17), 'MK_MAN', Decimal('17160.00'), None, 100, 20, 205920, 20, 'Marketing', 201, 1800, 1800, '147 Spadina Ave', 'M5V 2L7', 'Toronto', 'Ontario', 'CA', 'CA', 'Canada', 2)
# (202, 'Pat', 'Fay', 'PFAY', '603.123.6666', datetime.date(1997, 8, 17), 'MK_REP', Decimal('7200.00'), None, 201, 20, 86400, 20, 'Marketing', 201, 1800, 1800, '147 Spadina Ave', 'M5V 2L7', 'Toronto', 'Ontario', 'CA', 'CA', 'Canada', 2)
# (203, 'Susan', 'Mavris', 'SMAVRIS', '515.123.7777', datetime.date(1994, 6, 7), 'HR_REP', Decimal('7800.00'), None, 101, 40, 93600, 40, 'Human Resources', 203, 2400, 2400, '8204 Arthur St', None, 'London', None, 'UK', 'UK', 'United Kingdom', 1)
# (204, 'Hermann', 'Baer', 'HBAER', '515.123.8888', datetime.date(1994, 6, 7), 'PR_REP', Decimal('13200.00'), None, 101, 70, 158400, 70, 'Public Relations', 204, 2700, 2700, 'Schwanthalerstr. 7031', '80925', 'Munich', 'Bavaria', 'DE', 'DE', 'Germany', 1)
# (205, 'Shelley', 'Higgins', 'SHIGGINS', '515.123.8080', datetime.date(1994, 6, 7), 'AC_MGR', Decimal('15840.00'), None, 101, 110, 190080, 110, 'Accounting', 205, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)
# (206, 'William', 'Gietz', 'WGIETZ', '51hr5.123.8181', datetime.date(1994, 6, 7), 'AC_ACCOUNT', Decimal('9960.00'), None, 205, 110, 119520, 110, 'Accounting', 205, 1700, 1700, '2004 Charade Rd', '98199', 'Seattle', 'Washington', 'US', 'US', 'United States of America', 2)

# %%
df=pd.DataFrame(d)
df
# Out:
#       0          1        2         3               4           5   \
# 0    100     Steven     King     SKING    515.123.4567  1987-06-17
# 1    101      Neena  Kochhar  NKOCHHAR    515.123.4568  1989-09-21
# 2    102        Lex  De Haan   LDEHAAN    515.123.4569  1993-01-13
# 3    103  Alexander   Hunold   AHUNOLD    590.423.4567  1990-01-03
# 4    104      Bruce    Ernst    BERNST    590.423.4568  1991-05-21
# ..   ...        ...      ...       ...             ...         ...
# 102  202        Pat      Fay      PFAY    603.123.6666  1997-08-17
# 103  203      Susan   Mavris   SMAVRIS    515.123.7777  1994-06-07
# 104  204    Hermann     Baer     HBAER    515.123.8888  1994-06-07
# 105  205    Shelley  Higgins  SHIGGINS    515.123.8080  1994-06-07
# 106  206    William    Gietz    WGIETZ  51hr5.123.8181  1994-06-07
#
#              6         7     8      9   ...      15      16  \
# 0       AD_PRES  25200.00  None    NaN  ...  1700.0  1700.0
# 1         AD_VP  18700.00  None  100.0  ...  1700.0  1700.0
# 2         AD_VP  18700.00  None  100.0  ...  1700.0  1700.0
# 3       IT_PROG  11880.00  None  102.0  ...  1400.0  1400.0
# 4       IT_PROG   7200.00  None  103.0  ...  1400.0  1400.0
# ..          ...       ...   ...    ...  ...     ...     ...
# 102      MK_REP   7200.00  None  201.0  ...  1800.0  1800.0
# 103      HR_REP   7800.00  None  101.0  ...  2400.0  2400.0
# 104      PR_REP  13200.00  None  101.0  ...  2700.0  2700.0
# 105      AC_MGR  15840.00  None  101.0  ...  1700.0  1700.0
# 106  AC_ACCOUNT   9960.00  None  205.0  ...  1700.0  1700.0
#
#                         17       18         19          20  21  22  \
# 0          2004 Charade Rd    98199    Seattle  Washington  US  US
# 1          2004 Charade Rd    98199    Seattle  Washington  US  US
# 2          2004 Charade Rd    98199    Seattle  Washington  US  US
# 3      2014 Jabberwocky Rd    26192  Southlake       Texas  US  US
# 4      2014 Jabberwocky Rd    26192  Southlake       Texas  US  US
# ..                     ...      ...        ...         ...  ..  ..
# 102        147 Spadina Ave  M5V 2L7    Toronto     Ontario  CA  CA
# 103         8204 Arthur St     None     London        None  UK  UK
# 104  Schwanthalerstr. 7031    80925     Munich     Bavaria  DE  DE
# 105        2004 Charade Rd    98199    Seattle  Washington  US  US
# 106        2004 Charade Rd    98199    Seattle  Washington  US  US
#
#                            23   24
# 0    United States of America  2.0
# 1    United States of America  2.0
# 2    United States of America  2.0
# 3    United States of America  2.0
# 4    United States of America  2.0
# ..                        ...  ...
# 102                    Canada  2.0
# 103            United Kingdom  1.0
# 104                   Germany  1.0
# 105  United States of America  2.0
# 106  United States of America  2.0
#
# [107 rows x 25 columns]

# %%
q6=pd.read_sql_query(q5,db)
q6
# Out:
#      employee_id first_name last_name     email    phone_number   hire_date  \
# 0            100     Steven      King     SKING    515.123.4567  1987-06-17
# 1            101      Neena   Kochhar  NKOCHHAR    515.123.4568  1989-09-21
# 2            102        Lex   De Haan   LDEHAAN    515.123.4569  1993-01-13
# 3            103  Alexander    Hunold   AHUNOLD    590.423.4567  1990-01-03
# 4            104      Bruce     Ernst    BERNST    590.423.4568  1991-05-21
# ..           ...        ...       ...       ...             ...         ...
# 102          202        Pat       Fay      PFAY    603.123.6666  1997-08-17
# 103          203      Susan    Mavris   SMAVRIS    515.123.7777  1994-06-07
# 104          204    Hermann      Baer     HBAER    515.123.8888  1994-06-07
# 105          205    Shelley   Higgins  SHIGGINS    515.123.8080  1994-06-07
# 106          206    William     Gietz    WGIETZ  51hr5.123.8181  1994-06-07
#
#          job_id   salary  commission_pct  manager_id  ...  location_id  \
# 0       AD_PRES  25200.0             NaN         NaN  ...       1700.0
# 1         AD_VP  18700.0             NaN       100.0  ...       1700.0
# 2         AD_VP  18700.0             NaN       100.0  ...       1700.0
# 3       IT_PROG  11880.0             NaN       102.0  ...       1400.0
# 4       IT_PROG   7200.0             NaN       103.0  ...       1400.0
# ..          ...      ...             ...         ...  ...          ...
# 102      MK_REP   7200.0             NaN       201.0  ...       1800.0
# 103      HR_REP   7800.0             NaN       101.0  ...       2400.0
# 104      PR_REP  13200.0             NaN       101.0  ...       2700.0
# 105      AC_MGR  15840.0             NaN       101.0  ...       1700.0
# 106  AC_ACCOUNT   9960.0             NaN       205.0  ...       1700.0
#
#      location_id         street_address postal_code       city  \
# 0         1700.0        2004 Charade Rd       98199    Seattle
# 1         1700.0        2004 Charade Rd       98199    Seattle
# 2         1700.0        2004 Charade Rd       98199    Seattle
# 3         1400.0    2014 Jabberwocky Rd       26192  Southlake
# 4         1400.0    2014 Jabberwocky Rd       26192  Southlake
# ..           ...                    ...         ...        ...
# 102       1800.0        147 Spadina Ave     M5V 2L7    Toronto
# 103       2400.0         8204 Arthur St        None     London
# 104       2700.0  Schwanthalerstr. 7031       80925     Munich
# 105       1700.0        2004 Charade Rd       98199    Seattle
# 106       1700.0        2004 Charade Rd       98199    Seattle
#
#      state_province country_id country_id              country_name region_id
# 0        Washington         US         US  United States of America       2.0
# 1        Washington         US         US  United States of America       2.0
# 2        Washington         US         US  United States of America       2.0
# 3             Texas         US         US  United States of America       2.0
# 4             Texas         US         US  United States of America       2.0
# ..              ...        ...        ...                       ...       ...
# 102         Ontario         CA         CA                    Canada       2.0
# 103            None         UK         UK            United Kingdom       1.0
# 104         Bavaria         DE         DE                   Germany       1.0
# 105      Washington         US         US  United States of America       2.0
# 106      Washington         US         US  United States of America       2.0
#
# [107 rows x 25 columns]

# %%
# Task 2
q7=pd.read_sql_query('Select * from employees',db)
print(q7)
print(type(q7))
# Out:
#      employee_id first_name last_name     email    phone_number   hire_date  \
# 0            100     Steven      King     SKING    515.123.4567  1987-06-17
# 1            101      Neena   Kochhar  NKOCHHAR    515.123.4568  1989-09-21
# 2            102        Lex   De Haan   LDEHAAN    515.123.4569  1993-01-13
# 3            103  Alexander    Hunold   AHUNOLD    590.423.4567  1990-01-03
# 4            104      Bruce     Ernst    BERNST    590.423.4568  1991-05-21
# ..           ...        ...       ...       ...             ...         ...
# 102          202        Pat       Fay      PFAY    603.123.6666  1997-08-17
# 103          203      Susan    Mavris   SMAVRIS    515.123.7777  1994-06-07
# 104          204    Hermann      Baer     HBAER    515.123.8888  1994-06-07
# 105          205    Shelley   Higgins  SHIGGINS    515.123.8080  1994-06-07
# 106          206    William     Gietz    WGIETZ  51hr5.123.8181  1994-06-07
#
#          job_id   salary  commission_pct  manager_id  department_id  \
# 0       AD_PRES  25200.0             NaN         NaN           90.0
# 1         AD_VP  18700.0             NaN       100.0           90.0
# 2         AD_VP  18700.0             NaN       100.0           90.0
# 3       IT_PROG  11880.0             NaN       102.0           60.0
# 4       IT_PROG   7200.0             NaN       103.0           60.0
# ..          ...      ...             ...         ...            ...
# 102      MK_REP   7200.0             NaN       201.0           20.0
# 103      HR_REP   7800.0             NaN       101.0           40.0
# 104      PR_REP  13200.0             NaN       101.0           70.0
# 105      AC_MGR  15840.0             NaN       101.0          110.0
# 106  AC_ACCOUNT   9960.0             NaN       205.0          110.0
#
#      annual_CTC
# 0        302400
# 1        224400
# 2        224400
# 3        142560
# 4         86400
# ..          ...
# 102       86400
# 103       93600
# 104      158400
# 105      190080
# 106      119520
#
# [107 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
q8=pd.read_sql_query('select * from departments',db)
print(q8)
print(type(q8))
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# 13            140    Control And Credit         NaN         1700
# 14            150  Shareholder Services         NaN         1700
# 15            160              Benefits         NaN         1700
# 16            170         Manufacturing         NaN         1700
# 17            180          Construction         NaN         1700
# 18            190           Contracting         NaN         1700
# 19            200            Operations         NaN         1700
# 20            210            IT Support         NaN         1700
# 21            220                   NOC         NaN         1700
# 22            230           IT Helpdesk         NaN         1700
# 23            240      Government Sales         NaN         1700
# 24            250          Retail Sales         NaN         1700
# 25            260            Recruiting         NaN         1700
# 26            270               Payroll         NaN         1700
# <class 'pandas.core.frame.DataFrame'>

# %%
q9=pd.read_sql_query('select * from locations',db)
print(q9)
print(type(q9))
# Out:
#     location_id                            street_address  postal_code  \
# 0          1000                      1297 Via Cola di Rie        00989
# 1          1100                   93091 Calle della Testa        10934
# 2          1200                          2017 Shinjuku-ku         1689
# 3          1300                           9450 Kamiya-cho         6823
# 4          1400                       2014 Jabberwocky Rd        26192
# 5          1500                       2011 Interiors Blvd        99236
# 6          1600                            2007 Zagora St        50090
# 7          1700                           2004 Charade Rd        98199
# 8          1800                           147 Spadina Ave      M5V 2L7
# 9          1900                           6092 Boxwood St      YSW 9T2
# 10         2000                       40-5-12 Laogianggen       190518
# 11         2100                        1298 Vileparle (E)       490231
# 12         2200                     12-98 Victoria Street         2901
# 13         2300                        198 Clementi North       540198
# 14         2400                            8204 Arthur St         None
# 15         2500  Magdalen Centre, The Oxford Science Park      OX9 9ZB
# 16         2600                         9702 Chester Road  09629850293
# 17         2700                     Schwanthalerstr. 7031        80925
# 18         2800                     Rua Frei Caneca 1360     01307-002
# 19         2900                   20 Rue des Corps-Saints         1730
# 20         3000                         Murtenstrasse 921         3095
# 21         3100                 Pieter Breughelstraat 837       3029SK
# 22         3200                     Mariano Escobedo 9991        11932
#
#                    city     state_province country_id
# 0                  Roma               None         IT
# 1                Venice               None         IT
# 2                 Tokyo   Tokyo Prefecture         JP
# 3             Hiroshima               None         JP
# 4             Southlake              Texas         US
# 5   South San Francisco         California         US
# 6       South Brunswick         New Jersey         US
# 7               Seattle         Washington         US
# 8               Toronto            Ontario         CA
# 9            Whitehorse              Yukon         CA
# 10              Beijing               None         CN
# 11               Bombay        Maharashtra         IN
# 12               Sydney    New South Wales         AU
# 13            Singapore               None         SG
# 14               London               None         UK
# 15               Oxford             Oxford         UK
# 16            Stretford         Manchester         UK
# 17               Munich            Bavaria         DE
# 18            Sao Paulo          Sao Paulo         BR
# 19               Geneva             Geneve         CH
# 20                 Bern                 BE         CH
# 21              Utrecht            Utrecht         NL
# 22          Mexico City  Distrito Federal,         MX
# <class 'pandas.core.frame.DataFrame'>

# %%
q10=pd.read_sql_query('select * from countries',db)
print(q10)
print(type(q10))
# Out:
#    country_id              country_name  region_id
# 0          AR                 Argentina          2
# 1          AU                 Australia          3
# 2          BE                   Belgium          1
# 3          BR                    Brazil          2
# 4          CA                    Canada          2
# 5          CH               Switzerland          1
# 6          CN                     China          3
# 7          DE                   Germany          1
# 8          DK                   Denmark          1
# 9          EG                     Egypt          4
# 10         FR                    France          1
# 11         HK                  HongKong          3
# 12         IL                    Israel          4
# 13         IN                     India          3
# 14         IT                     Italy          1
# 15         JP                     Japan          3
# 16         KW                    Kuwait          4
# 17         MX                    Mexico          2
# 18         NG                   Nigeria          4
# 19         NL               Netherlands          1
# 20         SG                 Singapore          3
# 21         UK            United Kingdom          1
# 22         US  United States of America          2
# 23         ZM                    Zambia          4
# 24         ZW                  Zimbabwe          4
# <class 'pandas.core.frame.DataFrame'>

# %%
q11=pd.merge(q7,q8,on='department_id')

# %%
q12=pd.merge(q11,q9,on='location_id')

# %%
q13=pd.merge(q12,q10,on='country_id')
q13
# Out:
#      employee_id first_name  last_name     email        phone_number  \
# 0            100     Steven       King     SKING        515.123.4567
# 1            101      Neena    Kochhar  NKOCHHAR        515.123.4568
# 2            102        Lex    De Haan   LDEHAAN        515.123.4569
# 3            108      Nancy  Greenberg  NGREENBE        515.124.4569
# 4            109     Daniel     Faviet   DFAVIET        515.124.4169
# ..           ...        ...        ...       ...                 ...
# 101          179    Charles    Johnson  CJOHNSON  011.44.1644.429262
# 102          203      Susan     Mavris   SMAVRIS        515.123.7777
# 103          201    Michael  Hartstein  MHARTSTE        515.123.5555
# 104          202        Pat        Fay      PFAY        603.123.6666
# 105          204    Hermann       Baer     HBAER        515.123.8888
#
#       hire_date      job_id   salary  commission_pct  manager_id_x  ...  \
# 0    1987-06-17     AD_PRES  25200.0             NaN           NaN  ...
# 1    1989-09-21       AD_VP  18700.0             NaN         100.0  ...
# 2    1993-01-13       AD_VP  18700.0             NaN         100.0  ...
# 3    1994-08-17      FI_MGR  15840.0             NaN         101.0  ...
# 4    1994-08-16  FI_ACCOUNT  11880.0             NaN         108.0  ...
# ..          ...         ...      ...             ...           ...  ...
# 101  2000-01-04      SA_REP   7440.0             0.1         149.0  ...
# 102  1994-06-07      HR_REP   7800.0             NaN         101.0  ...
# 103  1996-02-17      MK_MAN  17160.0             NaN         100.0  ...
# 104  1997-08-17      MK_REP   7200.0             NaN         201.0  ...
# 105  1994-06-07      PR_REP  13200.0             NaN         101.0  ...
#
#       department_name  manager_id_y location_id  \
# 0           Executive         100.0        1700
# 1           Executive         100.0        1700
# 2           Executive         100.0        1700
# 3             Finance         108.0        1700
# 4             Finance         108.0        1700
# ..                ...           ...         ...
# 101             Sales         145.0        2500
# 102   Human Resources         203.0        2400
# 103         Marketing         201.0        1800
# 104         Marketing         201.0        1800
# 105  Public Relations         204.0        2700
#
#                                street_address  postal_code     city  \
# 0                             2004 Charade Rd        98199  Seattle
# 1                             2004 Charade Rd        98199  Seattle
# 2                             2004 Charade Rd        98199  Seattle
# 3                             2004 Charade Rd        98199  Seattle
# 4                             2004 Charade Rd        98199  Seattle
# ..                                        ...          ...      ...
# 101  Magdalen Centre, The Oxford Science Park      OX9 9ZB   Oxford
# 102                            8204 Arthur St         None   London
# 103                           147 Spadina Ave      M5V 2L7  Toronto
# 104                           147 Spadina Ave      M5V 2L7  Toronto
# 105                     Schwanthalerstr. 7031        80925   Munich
#
#     state_province country_id              country_name region_id
# 0       Washington         US  United States of America         2
# 1       Washington         US  United States of America         2
# 2       Washington         US  United States of America         2
# 3       Washington         US  United States of America         2
# 4       Washington         US  United States of America         2
# ..             ...        ...                       ...       ...
# 101         Oxford         UK            United Kingdom         1
# 102           None         UK            United Kingdom         1
# 103        Ontario         CA                    Canada         2
# 104        Ontario         CA                    Canada         2
# 105        Bavaria         DE                   Germany         1
#
# [106 rows x 22 columns]

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='hr',user='root',pw='Sukrit_1996'))
q13.to_sql('Employee_detail',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Employee_detail' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
engine=create_engine('mysql+pymysql://{user}:{pw}@{host}/{db}'.format(host='localhost:3306',db='hr',user='root',pw='Sukrit_1996'))
q6.to_sql('Employee_dtl',engine,index=False)
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Employee_dtl' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
# Task 3
plt.barh(q13.country_name,q13.employee_id)
# Out:
# <BarContainer object of 106 artists>

# %%
plt.barh(q13.city,q13.employee_id)
# Out:
# <BarContainer object of 106 artists>
