# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Task 1

# %%
df=pd.read_csv('cards.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df1=df.iloc[:,1:]
df1.dropna(inplace=True)
df1
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8943     5.871712           0.500000      20.90             20.90
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
catagory=df.dropna().iloc[:,:1]
type(catagory)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.preprocessing import MinMaxScaler
X=MinMaxScaler().fit_transform(df1)
X=pd.DataFrame(X,columns=df1.columns)
X
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 3     0.042940           1.000000   0.000326          0.000393
# 4     0.095038           1.000000   0.027188          0.000000
# ...        ...                ...        ...               ...
# 8631  0.000308           0.500000   0.000426          0.000513
# 8632  0.001496           1.000000   0.005936          0.000000
# 8633  0.001229           0.833333   0.002945          0.000000
# 8634  0.000707           0.833333   0.000000          0.000000
# 8635  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %% [markdown]
# ## the range of values for the dimensions in the dataset .Have visible difference. So, scaling is required.

# %% [markdown]
# # TASK 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(X.corr(),annot=True,cmap='rainbow')
plt.show()

# %%
name=[]
corr=[]
corr1=[]
for x in range(1,len(X.corr())):
    for y in range(x):
        name.append([X.corr().index[x],list(df1.corr().columns)[y]])
        corr.append(round(X.corr().iloc[x,y],2))
        corr1.append(np.sqrt((round(X.corr().iloc[x,y],2)**2)))

# %%
selection=pd.DataFrame([name,corr,corr1]).T
selection.columns=['name','correlation','correlation1']
selection
# Out:
#                                       name correlation correlation1
# 0             [BALANCE_FREQUENCY, BALANCE]        0.31         0.31
# 1                     [PURCHASES, BALANCE]        0.18         0.18
# 2           [PURCHASES, BALANCE_FREQUENCY]        0.12         0.12
# 3              [ONEOFF_PURCHASES, BALANCE]        0.16         0.16
# 4    [ONEOFF_PURCHASES, BALANCE_FREQUENCY]         0.1          0.1
# ..                                     ...         ...          ...
# 131                [TENURE, PURCHASES_TRX]        0.12         0.12
# 132                 [TENURE, CREDIT_LIMIT]        0.14         0.14
# 133                     [TENURE, PAYMENTS]         0.1          0.1
# 134             [TENURE, MINIMUM_PAYMENTS]        0.06         0.06
# 135             [TENURE, PRC_FULL_PAYMENT]       -0.02         0.02
#
# [136 rows x 3 columns]

# %%
Name=selection.sort_values(by='correlation',ascending=False).head(5)
Name.index=range(5)
Name
# Out:
#                                                 name correlation correlation1
# 0                      [ONEOFF_PURCHASES, PURCHASES]        0.92         0.92
# 1  [PURCHASES_INSTALLMENTS_FREQUENCY, PURCHASES_F...        0.86         0.86
# 2         [CASH_ADVANCE_TRX, CASH_ADVANCE_FREQUENCY]         0.8          0.8
# 3                         [PURCHASES_TRX, PURCHASES]        0.69         0.69
# 4                [INSTALLMENTS_PURCHASES, PURCHASES]        0.68         0.68

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
data=[]
dist=[]
for k in range(2,10):
    kmeans=KMeans(n_clusters=k,random_state=2)
    cluster=kmeans.fit(X)
    distorion=kmeans.inertia_
    cluster_label=cluster.predict(X)
    silhouette_avg = silhouette_score(X, cluster_label)
    dist.append(distorion)
    data.append(silhouette_avg)
    print('no. of cluster:',k,',distortion:',distorion,',silhouette avg:',silhouette_avg)
fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 10), dist)
plt.grid(True)
plt.title('Elbow curve')
plt.show()
fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 10), data)
plt.grid(True)
plt.title('silhouette avg')
plt.show()
# Out:
# no. of cluster: 2 ,distortion: 3300.7155556099287 ,silhouette avg: 0.3905501972265014
# no. of cluster: 3 ,distortion: 2739.006064689881 ,silhouette avg: 0.37651757663889607
# no. of cluster: 4 ,distortion: 2416.1406011591052 ,silhouette avg: 0.37615915850041204
# no. of cluster: 5 ,distortion: 2143.1461531647283 ,silhouette avg: 0.31580042456217844
# no. of cluster: 6 ,distortion: 1943.9904470551621 ,silhouette avg: 0.3201811129778893
# no. of cluster: 7 ,distortion: 1755.1128038312604 ,silhouette avg: 0.33636677146494465
# no. of cluster: 8 ,distortion: 1600.7025999817508 ,silhouette avg: 0.31731704685282147
# no. of cluster: 9 ,distortion: 1490.047681780928 ,silhouette avg: 0.3226001317741202

# %%
temp=pd.DataFrame([data,range(2,10)])
value=temp.T
value.columns=['score','k']
value['k']=value['k'].astype(int)
score=value.sort_values(by='score').iloc[-2,1]
value
# Out:
#       score  k
# 0  0.390550  2
# 1  0.376518  3
# 2  0.376159  4
# 3  0.315800  5
# 4  0.320181  6
# 5  0.336367  7
# 6  0.317317  8
# 7  0.322600  9

# %%
List=list(Name.loc[:,'name'])
for x in List:
    km  = X[x]
    kmeans = KMeans(n_clusters=score,n_init=score,random_state=2).fit(km)
    centroids = kmeans.cluster_centers_
    cluster=kmeans.predict(km)
    print(cluster)
    catagory[f'{x}']=cluster
#     print(centroids)
    print('Attributes used for cluster model: ', x)
    sns.scatterplot(X[x[0]], X[x[1]], hue= kmeans.labels_)
    plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
    plt.show()
# Out:
# [0 0 0 ... 0 0 0]
# Attributes used for cluster model:  ['ONEOFF_PURCHASES', 'PURCHASES']
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [0 0 2 ... 1 0 2]
# Attributes used for cluster model:  ['PURCHASES_INSTALLMENTS_FREQUENCY', 'PURCHASES_FREQUENCY']
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [0 2 0 ... 0 2 2]
# Attributes used for cluster model:  ['CASH_ADVANCE_TRX', 'CASH_ADVANCE_FREQUENCY']
# ...

# %%
catagory
# Out:
#      CUST_ID  ['ONEOFF_PURCHASES', 'PURCHASES']  \
# 0     C10001                                  0
# 1     C10002                                  0
# 2     C10003                                  0
# 4     C10005                                  0
# 5     C10006                                  0
# ...      ...                                ...
# 8943  C19184                                  0
# 8945  C19186                                  0
# 8947  C19188                                  0
# 8948  C19189                                  0
# 8949  C19190                                  0
#
#       ['PURCHASES_INSTALLMENTS_FREQUENCY', 'PURCHASES_FREQUENCY']  \
# 0                                                     0
# 1                                                     0
# 2                                                     2
# 4                                                     0
# 5                                                     2
# ...

# %%
catagory1=df.dropna().iloc[:,:1]
type(catagory1)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.cluster import  AgglomerativeClustering
List1=list(Name.loc[:,'name'])
for z in List1:
    A=X[z]
    model = AgglomerativeClustering(n_clusters= score, linkage = 'ward')
    Model = model.fit_predict(A)
    catagory1[f'{z}']=Model
    print('n_clusters=',score,'linkage =',x)
    sns.scatterplot(X[z[0]], X[z[1]],hue=model.labels_)
    plt.title(f"Agglomerative{z}")
    plt.show()
# Out:
# n_clusters= 3 linkage = ['INSTALLMENTS_PURCHASES', 'PURCHASES']
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# n_clusters= 3 linkage = ['INSTALLMENTS_PURCHASES', 'PURCHASES']
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# n_clusters= 3 linkage = ['INSTALLMENTS_PURCHASES', 'PURCHASES']
# ...

# %%
catagory1
# Out:
#      CUST_ID  ['ONEOFF_PURCHASES', 'PURCHASES']  \
# 0     C10001                                  2
# 1     C10002                                  2
# 2     C10003                                  2
# 4     C10005                                  2
# 5     C10006                                  2
# ...      ...                                ...
# 8943  C19184                                  2
# 8945  C19186                                  2
# 8947  C19188                                  2
# 8948  C19189                                  2
# 8949  C19190                                  2
#
#       ['PURCHASES_INSTALLMENTS_FREQUENCY', 'PURCHASES_FREQUENCY']  \
# 0                                                     2
# 1                                                     2
# 2                                                     0
# 4                                                     2
# 5                                                     0
# ...

# %% [markdown]
# # TASK 3

# %%
List=['ONEOFF_PURCHASES','PURCHASES','PURCHASES_INSTALLMENTS_FREQUENCY','PURCHASES_FREQUENCY','CASH_ADVANCE_TRX','CASH_ADVANCE_FREQUENCY','PURCHASES_TRX','INSTALLMENTS_PURCHASES']
for x in range(len(List)-2):
    for y in range(x+1,len(List)-1):
        for z in range(y+1,len(List)):
            fig = plt.figure(figsize=(10, 5))
            xs = X[List[x]]
            ys = X[List[y]]
            zs = X[List[z]]
            plt.scatter(xs, ys,s=zs,color='r')
            plt.xlabel(List[x])
            plt.ylabel(List[y])
            plt.show()

# %% [markdown]
# # PCA

# %%
import warnings                                                  
warnings.filterwarnings("ignore")

from sklearn.decomposition import PCA
A=X
catagory2=df.dropna().iloc[:,:1]
values = PCA().fit_transform(A)
cluster = KMeans(n_clusters=score).fit_predict(values)
df_plot = A.copy()
df_plot['PCA_Km_feature'] = cluster
catagory2['PCA_Km_feature'] = cluster
sns.scatterplot(df_plot.iloc[:,0],df_plot.iloc[:,1], hue=df_plot['PCA_Km_feature'])
plt.show()

# %%
from sklearn.manifold import TSNE
values = PCA().fit_transform(A)
cluster = KMeans(n_clusters=score).fit_predict(values)
df_plot1 = pd.DataFrame(values)
df_plot1['PCA_Km(value)'] = cluster
catagory2['PCA_Km(value)'] = cluster
sns.scatterplot(df_plot1.iloc[:,0],df_plot1.iloc[:,1], hue=df_plot1['PCA_Km(value)'])
plt.show()

# %% [markdown]
# # TSNE

# %%
values = TSNE().fit_transform(A)
cluster = KMeans(n_clusters=score).fit_predict(values)
df_plot = A.copy()
df_plot['TSNE_Km(feature)'] = cluster
catagory2['TSNE_Km(feature)'] = cluster
sns.scatterplot(df_plot.iloc[:,0],df_plot.iloc[:,1], hue=df_plot['TSNE_Km(feature)'])
plt.show()

# %%
values = TSNE().fit_transform(A)
cluster = KMeans(n_clusters=score).fit_predict(values)
df_plot1 = pd.DataFrame(values)
df_plot1['TSNE_Km(value)'] = cluster
catagory2['TSNE_Km(value)'] = cluster
sns.scatterplot(df_plot1.iloc[:,0],df_plot1.iloc[:,1], hue=df_plot1['TSNE_Km(value)'])
plt.show()

# %% [markdown]
# # AGGLOMERATIVE

# %% [markdown]
# # PCA

# %%
values = PCA().fit_transform(A)
cluster = AgglomerativeClustering(n_clusters= score, linkage = 'ward').fit_predict(values)
df_plot = A.copy()
df_plot['PCA_A(feature)'] = cluster
catagory2['PCA_A(feature)'] = cluster
sns.scatterplot(df_plot.iloc[:,0],df_plot.iloc[:,1], hue=df_plot['PCA_A(feature)'])
plt.show()

# %%
values = PCA().fit_transform(A)
cluster = AgglomerativeClustering(n_clusters= score, linkage = 'ward').fit_predict(values)
df_plot1 = pd.DataFrame(values)
df_plot1['PCA_A(value)'] = cluster
catagory2['PCA_A(value)'] = cluster
sns.scatterplot(df_plot1.iloc[:,0],df_plot1.iloc[:,1], hue=df_plot1['PCA_A(value)'])
plt.show()

# %% [markdown]
# # TSNE

# %%
values = TSNE().fit_transform(A)
cluster = AgglomerativeClustering(n_clusters= score, linkage = 'ward').fit_predict(values)
df_plot = A.copy()
df_plot['TSNE_A(feature)'] = cluster
catagory2['TSNE_A(feature)'] = cluster
sns.scatterplot(df_plot.iloc[:,0],df_plot.iloc[:,1], hue=df_plot['TSNE_A(feature)'])
plt.show()

# %%
values = TSNE().fit_transform(A)
cluster = AgglomerativeClustering(n_clusters= score, linkage = 'ward').fit_predict(values)
df_plot1 = pd.DataFrame(values)
df_plot1['TSNE_A(Value)'] = cluster
catagory2['TSNE_A(Value)'] = cluster
sns.scatterplot(df_plot1.iloc[:,0],df_plot1.iloc[:,1], hue=df_plot1['TSNE_A(Value)'])
plt.show()

# %% [markdown]
# # TASK 4

# %% [markdown]
# The result result changed with the different models as well as for both dimension reduction methord.

# %% [markdown]
# run time is assending order , kmean , Agglomerative ,dbscan , hdbscan , dimension reduction (PCA), dimension reduction(TSNE)

# %%
catagory2
# Out:
#      CUST_ID  PCA_Km_feature  PCA_Km(value)  TSNE_Km(feature)  TSNE_Km(value)  \
# 0     C10001               1              1                 0               2
# 1     C10002               1              1                 2               2
# 2     C10003               0              2                 0               1
# 4     C10005               1              1                 2               2
# 5     C10006               2              0                 1               0
# ...      ...             ...            ...               ...             ...
# 8943  C19184               1              1                 1               2
# 8945  C19186               2              0                 0               1
# 8947  C19188               2              0                 0               1
# 8948  C19189               1              1                 1               2
# 8949  C19190               0              2                 1               1
#
# ...

# %% [markdown]
# yes, the few characteristics changes with the different model. because of different clustering methord
