# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('Car_sales.csv')
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.drop(columns='__year_resale_value',axis=1,inplace=True)
df.dropna(inplace=True)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 3          Acura       RL               8.588    Passenger
# 4           Audi       A4              20.397    Passenger
# 5           Audi       A6              18.780    Passenger
# ..           ...      ...                 ...          ...
# 152        Volvo      V40               3.545    Passenger
# 153        Volvo      S70              15.245    Passenger
# 154        Volvo      V70              17.531    Passenger
# 155        Volvo      C70               3.493    Passenger
# 156        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
df.index=range(len(df))
df
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       RL               8.588    Passenger
# 3           Audi       A4              20.397    Passenger
# 4           Audi       A6              18.780    Passenger
# ..           ...      ...                 ...          ...
# 147        Volvo      V40               3.545    Passenger
# 148        Volvo      S70              15.245    Passenger
# 149        Volvo      V70              17.531    Passenger
# 150        Volvo      C70               3.493    Passenger
# 151        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
df['Latest_Launch']=df['Latest_Launch'].astype('datetime64[ns]')
df['Latest_Launch'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
numerical=[]
for x in df.columns:
    if df[x].dtypes != 'O' and df[x].dtypes != '<M8[ns]' :
        numerical.append(x)
    else:
        continue

# %%
df1=df[numerical]
df1
# Out:
#      Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# 0                16.919               21.50          1.8       140.0
# 1                39.384               28.40          3.2       225.0
# 2                 8.588               42.00          3.5       210.0
# 3                20.397               23.99          1.8       150.0
# 4                18.780               33.95          2.8       200.0
# ..                  ...                 ...          ...         ...
# 147               3.545               24.40          1.9       160.0
# 148              15.245               27.50          2.4       168.0
# 149              17.531               28.80          2.4       168.0
# 150               3.493               45.50          2.3       236.0
# 151              18.969               36.00          2.9       201.0
#
#      Wheelbase  Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
df2=StandardScaler().fit_transform(df1)
df2
# Out:
# array([[-0.53033645, -0.40580037, -1.19398947, ..., -1.21265887,
#          0.96906987, -0.73408212],
#        [-0.20338846,  0.07432786,  0.14398293, ..., -0.19344876,
#          0.26986756,  0.5843739 ],
#        [-0.651583  ,  1.02066756,  0.43069131, ...,  0.01039326,
#         -0.42933475,  0.585131  ],
#        ...,
#        [-0.52142961,  0.10216138, -0.62057273, ..., -0.01508699,
#          0.26986756, -0.22106034],
#        [-0.7257339 ,  1.26421087, -0.71614219, ...,  0.13779452,
#         -0.19626732,  0.99287552],
#        [-0.50050145,  0.60316475, -0.14272544, ...,  0.8002811 ,
#          0.03680012,  0.35984924]])

# %%
df3=pd.DataFrame(df2,columns=df1.columns)
df3
# Out:
#      Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# 0             -0.530336           -0.405800    -1.193989   -0.791180
# 1             -0.203388            0.074328     0.143983    0.709634
# 2             -0.651583            1.020668     0.430691    0.444785
# 3             -0.479719           -0.232537    -1.193989   -0.614614
# 4             -0.503252            0.460518    -0.238295    0.268218
# ..                  ...                 ...          ...         ...
# 147           -0.724977           -0.204007    -1.098420   -0.438047
# 148           -0.554699            0.011702    -0.620573   -0.296794
# 149           -0.521430            0.102161    -0.620573   -0.296794
# 150           -0.725734            1.264211    -0.716142    0.903857
# 151           -0.500501            0.603165    -0.142725    0.285875
#
#      Wheelbase     Width    Length  Curb_weight  Fuel_capacity  \
# 0    -0.807785 -1.097174 -1.091782    -1.161844      -1.212659
# ...

# %% [markdown]
# # TASK 1

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm

distorsions = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    clusterer=kmeans.fit(df3)
    distorsions.append(kmeans.inertia_)
    cluster_labels = clusterer.predict(df3)
    silhouette_avg = silhouette_score(df3, cluster_labels)
    print("For k =",k,"The average silhouette_score is :", silhouette_avg)
fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 11), distorsions)
plt.grid(True)
plt.title('Elbow curve')
plt.show()
# Out:
# For k = 2 The average silhouette_score is : 0.3200306295433135
# For k = 3 The average silhouette_score is : 0.2664552216594861
# For k = 4 The average silhouette_score is : 0.29316358047739155
# For k = 5 The average silhouette_score is : 0.22486547112530217
# For k = 6 The average silhouette_score is : 0.23984115649641813
# For k = 7 The average silhouette_score is : 0.24726319421563323
# For k = 8 The average silhouette_score is : 0.21279164813908255
# For k = 9 The average silhouette_score is : 0.21984192726543536
# For k = 10 The average silhouette_score is : 0.21601587033345773

# %%
for k in range(2, 11):
    fig, ax1 = plt.subplots(1, 1)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(df) + (k + 1) * 10])

    clusterer = KMeans(n_clusters=k, random_state=10)
    cluster_labels = clusterer.fit_predict(df3)

    silhouette_avg = silhouette_score(df3, cluster_labels)
    print("For n_clusters =", k,
          "The average silhouette_score is :", silhouette_avg)
    sample_silhouette_values = silhouette_samples(df3, cluster_labels)

    y_lower = 10
    for i in range(k):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / k)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10

    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax1.set_yticks([]) 
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3200306295433135
# For n_clusters = 3 The average silhouette_score is : 0.2664552216594861
# For n_clusters = 4 The average silhouette_score is : 0.28379681729969036
# For n_clusters = 5 The average silhouette_score is : 0.21375688939216053
# For n_clusters = 6 The average silhouette_score is : 0.23753271595758257
# For n_clusters = 7 The average silhouette_score is : 0.24322258840102293
# For n_clusters = 8 The average silhouette_score is : 0.23350279670597182
# For n_clusters = 9 The average silhouette_score is : 0.20743067658509412
# For n_clusters = 10 The average silhouette_score is : 0.21149995872969304

# %% [markdown]
# # TASK 2

# %%
from sklearn.cluster import KMeans

for x in range(len(df3.columns)-1):
    for y in range(x+1,len(df3.columns)):
        df4  = df3[[df3.head(0).iloc[:,x].name,df3.head(0).iloc[:,y].name]]
        kmeans = KMeans(n_clusters=3,n_init=3).fit(df4)
        centroids = kmeans.cluster_centers_
        print('\n',df3.head(0).iloc[:,x].name,'VS',df3.head(0).iloc[:,y].name)
        print('\n')
        print(centroids)
        plt.scatter(df4[df3.head(0).iloc[:,x].name], df4[df3.head(0).iloc[:,y].name], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
        plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
        plt.xlabel(df3.head(0).iloc[:,x].name)
        plt.ylabel(df3.head(0).iloc[:,y].name)
        plt.show()
# Out:
#  Sales_in_thousands VS Price_in_thousands
#
#
# [[-0.18332638 -0.36947631]
#  [-0.59425273  1.63133965]
#  [ 2.32876113 -0.61098126]]
#  Sales_in_thousands VS Engine_size
#
#
# [[-0.28220598  0.94207174]
#  [ 2.32876113 -0.08896762]
#  [-0.26803085 -0.66170389]]
#  Sales_in_thousands VS Horsepower
#
#
# [[-0.20698352 -0.43988647]
#  [ 2.32876113 -0.51529502]
#  [-0.434744    1.26184553]]
#  Sales_in_thousands VS Wheelbase
#
#
# [[-0.16837285  0.72795702]
#  [-0.27611975 -0.66510823]
#  [ 2.6916415   0.91035856]]
#  Sales_in_thousands VS Width
#
#
# [[-0.25069957 -0.71047547]
#  [-0.20245402  0.91442417]
#  [ 2.6916415   0.43519889]]
#  Sales_in_thousands VS Length
#
#
# [[-0.24190592  0.75748463]
#  [-0.28220922 -0.81578985]
#  [ 2.39748946  0.42358795]]
#  Sales_in_thousands VS Curb_weight
#
#
# [[-0.16938673 -0.64962559]
#  [ 2.6916415   0.07010686]
#  [-0.32001052  0.93118669]]
#  Sales_in_thousands VS Fuel_capacity
#
#
# [[-0.26714032 -0.34858517]
#  [-0.23260918  1.66660969]
# ...

# %%
kmeans.labels_
# Out:
# array([1, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 0, 1, 2, 2, 2, 2,
#        0, 1, 1, 2, 2, 2, 2, 1, 0, 0, 1, 2, 2, 0, 0, 0, 2, 2, 0, 2, 1, 2,
#        2, 2, 1, 2, 0, 2, 0, 2, 0, 1, 1, 2, 0, 2, 1, 1, 2, 2, 0, 2, 2, 2,
#        2, 2, 0, 0, 0, 0, 0, 0, 0, 1, 2, 2, 2, 2, 0, 2, 1, 1, 2, 2, 0, 2,
#        2, 2, 0, 0, 2, 2, 2, 0, 0, 1, 2, 2, 2, 2, 2, 2, 2, 1, 0, 2, 2, 1,
#        1, 2, 0, 1, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1,
#        1, 2, 1, 2, 2, 1, 2, 0, 1, 1, 1, 1, 1, 1, 2, 2, 2, 2, 0, 2])

# %%
df['cluster']=kmeans.labels_
df
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       RL               8.588    Passenger
# 3           Audi       A4              20.397    Passenger
# 4           Audi       A6              18.780    Passenger
# ..           ...      ...                 ...          ...
# 147        Volvo      V40               3.545    Passenger
# 148        Volvo      S70              15.245    Passenger
# 149        Volvo      V70              17.531    Passenger
# 150        Volvo      C70               3.493    Passenger
# 151        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
df6=df['cluster'].groupby(df['cluster'])
for x in df['cluster'].unique():
    ind=df6.get_group(x).index
    print(x)
    df4  = df3[['Fuel_efficiency','Power_perf_factor']].iloc[ind,:]
    plt.scatter(df4['Fuel_efficiency'], df4['Power_perf_factor'], )
    plt.xlabel('Fuel_efficiency')
    plt.ylabel('Power_perf_factor')
    plt.show()
# Out:
# 1
# 2
# 0

# %%
for x in range(len(df)):
    if df['cluster'][x]==0:
        df['cluster'][x]='hatchback'
    elif df['cluster'][x]==1:
        df['cluster'][x]='sports'
    else :
        df['cluster'][x]='suv'
# Out:
# C:\Users\krish\AppData\Local\Temp/ipykernel_16364/3079274902.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'][x]='sports'
# C:\Users\krish\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       RL               8.588    Passenger
# 3           Audi       A4              20.397    Passenger
# 4           Audi       A6              18.780    Passenger
# ..           ...      ...                 ...          ...
# 147        Volvo      V40               3.545    Passenger
# 148        Volvo      S70              15.245    Passenger
# 149        Volvo      V70              17.531    Passenger
# 150        Volvo      C70               3.493    Passenger
# 151        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
import seaborn as sns
plt.pie(df['cluster'].value_counts(),labels=df['cluster'].value_counts().index,autopct="%0.01f%%")
plt.show()
