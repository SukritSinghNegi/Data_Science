# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('DS3_C1_S3_DailyDelhiClimateTrain_Data_Practice.csv',parse_dates=['date'])
train
# Out:
#            date   meantemp    humidity  wind_speed  meanpressure
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...         ...        ...         ...         ...           ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
test=pd.read_csv('DS3_C1_S3_DailyDelhiClimateTest_Data_Practice.csv',parse_dates=['date'])
test
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..         ...        ...        ...         ...           ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
train=train.set_index('date')
print(train)
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
test=test.set_index('date')
print(test)
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 4 columns]

# %%
temp=train[['meantemp']]
print(temp.head())
# Out:
#              meantemp
# date
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %%
temp_test=test[['meantemp']]
temp_test.head()
# Out:
#              meantemp
# date
# 2017-01-01  15.913043
# 2017-01-02  18.500000
# 2017-01-03  17.111111
# 2017-01-04  18.700000
# 2017-01-05  18.388889

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import SimpleExpSmoothing
from statsmodels.tsa.api import ExponentialSmoothing

decomposition=seasonal_decompose(np.asarray(temp), period=12)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

fig,ax = plt.subplots(6,1,figsize=(20,20))

plt.subplot(612)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(613)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(611)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.subplot(614)
plt.plot(temp,label='meantemp')
plt.legend(loc='best')

plt.subplot(615)
plt.plot(temp.rolling(window=7).mean(),label='week')
plt.legend(loc='best')

plt.subplot(616)
plt.plot(temp.rolling(window=30).mean(),label='month')
plt.legend(loc='best')

plt.tight_layout()

# %%
temp_week=temp.rolling(window=7).mean()
temp_week.dropna(inplace=True)
temp_week
# Out:
#              meantemp
# date
# 2013-01-07   7.604762
# 2013-01-08   7.441497
# 2013-01-09   8.384354
# 2013-01-10   8.931973
# 2013-01-11   9.938776
# ...               ...
# 2016-12-28  16.480592
# 2016-12-29  16.188075
# 2016-12-30  15.980252
# 2016-12-31  15.656602
# 2017-01-01  15.085173
#
# [1456 rows x 1 columns]

# %% [markdown]
# # TASK 2

# %%
from statsmodels.tsa.stattools import adfuller,acf,pacf
def checkStationarity(data):
    pvalue = adfuller(data)[1]   
    if(pvalue>0.05):
        msg = 'p-value={}. temp_week is not stationary'.format(pvalue)
    else:
        msg='p-value={}. temp_week is stationary'.format(pvalue)
        
    return(msg)

# %%
ret=checkStationarity(temp_week); ret
# Out:
# 'p-value=0.0725238611640058. temp_week is not stationary'

# %%
diff_temp = temp_week - temp_week.shift()
diff_temp.dropna(inplace=True)
diff_temp
# Out:
#             meantemp
# date
# 2013-01-08 -0.163265
# 2013-01-09  0.942857
# 2013-01-10  0.547619
# 2013-01-11  1.006803
# 2013-01-12  1.142857
# ...              ...
# 2016-12-28 -0.118944
# 2016-12-29 -0.292517
# 2016-12-30 -0.207823
# 2016-12-31 -0.323650
# 2017-01-01 -0.571429
#
# [1455 rows x 1 columns]

# %%
ret=checkStationarity(diff_temp); ret
# Out:
# 'p-value=4.1866103935474905e-06. temp_week is stationary'

# %%
diff_temp
# Out:
#             meantemp
# date
# 2013-01-08 -0.163265
# 2013-01-09  0.942857
# 2013-01-10  0.547619
# 2013-01-11  1.006803
# 2013-01-12  1.142857
# ...              ...
# 2016-12-28 -0.118944
# 2016-12-29 -0.292517
# 2016-12-30 -0.207823
# 2016-12-31 -0.323650
# 2017-01-01 -0.571429
#
# [1455 rows x 1 columns]

# %%
diff_temp_test = temp_test - temp_test.shift()
diff_temp_test.dropna(inplace=True)
diff_temp_test
# Out:
#             meantemp
# date
# 2017-01-02  2.586957
# 2017-01-03 -1.388889
# 2017-01-04  1.588889
# 2017-01-05 -0.311111
# 2017-01-06  0.929293
# ...              ...
# 2017-04-20  1.000000
# 2017-04-21 -0.250000
# 2017-04-22 -1.350000
# 2017-04-23 -0.025000
# 2017-04-24 -0.875000
#
# [113 rows x 1 columns]

# %%
ret=checkStationarity(diff_temp_test); ret
# Out:
# 'p-value=2.8053213689778235e-22. temp_week is stationary'

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig,ax=plt.subplots(2,1,figsize=(20,10))
plot_acf(diff_temp,lags=40,ax=ax[0])
plot_pacf(diff_temp,lags=40,ax=ax[1])
plt.show()

# %% [markdown]
# # TASK 3

# %%
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
for p in range(1,4):
    for q in range(1,4):
        m1 = ARIMA(diff_temp,order=(p,0,q)).fit()
        print(m1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -372.933
# Date:                Wed, 27 Apr 2022   AIC                            753.866
# Time:                        13:28:54   BIC                            774.997
# Sample:                    01-08-2013   HQIC                           761.750
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0040      0.026      0.155      0.877      -0.047       0.055
# ar.L1          0.6906      0.026     26.543      0.000       0.640       0.742
# ma.L1         -0.0190      0.035     -0.539      0.590      -0.088       0.050
# sigma2         0.0977      0.003     35.201      0.000       0.092       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               172.65
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.07
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -369.548
# Date:                Wed, 27 Apr 2022   AIC                            749.095
# Time:                        13:28:56   BIC                            775.509
# Sample:                    01-08-2013   HQIC                           758.950
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.025      0.166      0.868      -0.044       0.052
# ar.L1          0.6156      0.041     15.196      0.000       0.536       0.695
# ma.L1          0.0570      0.046      1.247      0.212      -0.033       0.147
# ma.L2          0.0957      0.035      2.750      0.006       0.027       0.164
# sigma2         0.0973      0.003     34.607      0.000       0.092       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               159.83
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.06
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(1, 0, 3)   Log Likelihood                -369.360
# Date:                Wed, 27 Apr 2022   AIC                            750.720
# Time:                        13:28:56   BIC                            782.417
# Sample:                    01-08-2013   HQIC                           762.547
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.025      0.166      0.868      -0.044       0.053
# ar.L1          0.6312      0.063     10.053      0.000       0.508       0.754
# ma.L1          0.0408      0.067      0.606      0.544      -0.091       0.172
# ma.L2          0.0891      0.047      1.913      0.056      -0.002       0.180
# ma.L3         -0.0172      0.038     -0.458      0.647      -0.091       0.056
# sigma2         0.0972      0.003     34.557      0.000       0.092       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               159.13
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.06
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -356.574
# Date:                Wed, 27 Apr 2022   AIC                            723.147
# Time:                        13:28:58   BIC                            749.561
# Sample:                    01-08-2013   HQIC                           733.002
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.027      0.155      0.877      -0.048       0.056
# ar.L1         -0.2367      0.035     -6.842      0.000      -0.304      -0.169
# ar.L2          0.6632      0.021     31.231      0.000       0.622       0.705
# ma.L1          0.8872      0.036     24.987      0.000       0.818       0.957
# sigma2         0.0955      0.003     35.252      0.000       0.090       0.101
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.83   Jarque-Bera (JB):               163.63
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.07
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                -357.076
# Date:                Wed, 27 Apr 2022   AIC                            726.151
# Time:                        13:28:59   BIC                            757.848
# Sample:                    01-08-2013   HQIC                           737.977
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.018      0.210      0.834      -0.032       0.040
# ar.L1          1.5657      0.060     26.089      0.000       1.448       1.683
# ar.L2         -0.6860      0.042    -16.507      0.000      -0.767      -0.605
# ma.L1         -0.9333      0.064    -14.516      0.000      -1.059      -0.807
# ma.L2          0.2034      0.034      5.972      0.000       0.137       0.270
# sigma2         0.0956      0.003     34.244      0.000       0.090       0.101
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):               139.20
# Prob(Q):                              0.54   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.06
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(2, 0, 3)   Log Likelihood                   0.000
# Date:                Wed, 27 Apr 2022   AIC                             14.000
# Time:                        13:29:01   BIC                             50.979
# Sample:                    01-08-2013   HQIC                            27.797
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1606         -0       -inf      0.000       4.161       4.161
# ar.L1      -3.374e-06   1.07e-08   -314.766      0.000   -3.39e-06   -3.35e-06
# ar.L2          1.0000   4.55e-08    2.2e+07      0.000       1.000       1.000
# ma.L1          1.2141         -0       -inf      0.000       1.214       1.214
# ma.L2         -0.5709         -0        inf      0.000      -0.571      -0.571
# ma.L3         -0.7851         -0        inf      0.000      -0.785      -0.785
# sigma2        15.8706         -0       -inf      0.000      15.871      15.871
# ===================================================================================
# Ljung-Box (L1) (Q):                    nan   Jarque-Bera (JB):               545.62
# Prob(Q):                               nan   Prob(JB):                         0.00
# Heteroskedasticity (H):                nan   Skew:                             0.00
# Prob(H) (two-sided):                   nan   Kurtosis:                         0.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(3, 0, 1)   Log Likelihood                -352.980
# Date:                Wed, 27 Apr 2022   AIC                            717.960
# Time:                        13:29:03   BIC                            749.657
# Sample:                    01-08-2013   HQIC                           729.786
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.025      0.165      0.869      -0.045       0.053
# ar.L1         -0.1651      0.046     -3.618      0.000      -0.254      -0.076
# ar.L2          0.6351      0.025     25.605      0.000       0.586       0.684
# ar.L3         -0.0748      0.027     -2.740      0.006      -0.128      -0.021
# ma.L1          0.8589      0.039     22.093      0.000       0.783       0.935
# sigma2         0.0951      0.003     35.397      0.000       0.090       0.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               179.04
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.09
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(3, 0, 2)   Log Likelihood                -252.545
# Date:                Wed, 27 Apr 2022   AIC                            519.091
# Time:                        13:29:06   BIC                            556.070
# Sample:                    01-08-2013   HQIC                           532.888
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.024      0.113      0.910      -0.045       0.050
# ar.L1          0.2772      0.022     12.431      0.000       0.234       0.321
# ar.L2         -0.4637      0.019    -24.851      0.000      -0.500      -0.427
# ar.L3          0.4170      0.020     20.488      0.000       0.377       0.457
# ma.L1          0.4463      0.005     91.967      0.000       0.437       0.456
# ma.L2          0.9992      0.018     55.032      0.000       0.964       1.035
# sigma2         0.0819      0.003     27.792      0.000       0.076       0.088
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                86.89
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                            -0.23
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(3, 0, 3)   Log Likelihood                -252.101
# Date:                Wed, 27 Apr 2022   AIC                            520.201
# Time:                        13:29:10   BIC                            562.464
# Sample:                    01-08-2013   HQIC                           535.970
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0069      0.025      0.272      0.785      -0.042       0.056
# ar.L1          0.3466      0.052      6.621      0.000       0.244       0.449
# ar.L2         -0.4729      0.020    -24.069      0.000      -0.511      -0.434
# ar.L3          0.4478      0.029     15.544      0.000       0.391       0.504
# ma.L1          0.3587      0.058      6.203      0.000       0.245       0.472
# ma.L2          0.9598      0.029     32.886      0.000       0.903       1.017
# ma.L3         -0.0864      0.057     -1.516      0.130      -0.198       0.025
# sigma2         0.0824      0.003     30.397      0.000       0.077       0.088
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                83.99
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                            -0.22
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ARIMA (3,0,2) [LLR = -252.545 , AIC=519 , BIC=556 ,HQIC =532]

# %%
m1 = ARIMA(diff_temp,order=(3,0,2)).fit()
print(m1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               meantemp   No. Observations:                 1455
# Model:                 ARIMA(3, 0, 2)   Log Likelihood                -252.545
# Date:                Wed, 27 Apr 2022   AIC                            519.091
# Time:                        13:29:13   BIC                            556.070
# Sample:                    01-08-2013   HQIC                           532.888
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.024      0.113      0.910      -0.045       0.050
# ar.L1          0.2772      0.022     12.431      0.000       0.234       0.321
# ar.L2         -0.4637      0.019    -24.851      0.000      -0.500      -0.427
# ar.L3          0.4170      0.020     20.488      0.000       0.377       0.457
# ma.L1          0.4463      0.005     91.967      0.000       0.437       0.456
# ma.L2          0.9992      0.018     55.032      0.000       0.964       1.035
# sigma2         0.0819      0.003     27.792      0.000       0.076       0.088
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                86.89
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                            -0.23
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
m1.aic,m1.bic,m1.hqic
# Out:
# (519.0909994436636, 556.0703277009027, 532.8881404686297)

# %%
predictions=m1.predict(0,len(diff_temp_test))
predictions
# Out:
# 2013-01-08    0.002734
# 2013-01-09   -0.110326
# 2013-01-10    0.648648
# 2013-01-11    0.493548
# 2013-01-12    0.550071
#                 ...
# 2013-04-27    0.006643
# 2013-04-28    0.103786
# 2013-04-29    0.381518
# 2013-04-30    0.466197
# 2013-05-01    0.205214
# Freq: D, Name: predicted_mean, Length: 114, dtype: float64

# %%
actual=[]
predicted=[]
for i in range(len(diff_temp_test)):
    actual.append(diff_temp_test.iloc[i,0])
    predicted.append(predictions.iloc[i])
    
df_res = pd.DataFrame({'actual':actual, 'predicted':predicted})
df_res['err'] = df_res.actual - df_res.predicted

# %%
from sklearn.metrics import mean_squared_error
msg = 'ARMA Model. Order=(' + str(p) + ',' + str(q) + ')'
mse1 = mean_squared_error(df_res.actual, df_res.predicted)
print(msg + "\n\tMSE = {}\n\tRMSE = {}".format(mse1,np.sqrt(mse1)))
# Out:
# ARMA Model. Order=(3,3)
# 	MSE = 3.019695726577356
# 	RMSE = 1.7377271726532206

# %%
ax=plt.subplots(figsize=(15,8))
plt.plot(actual,label='actual temperature')
plt.plot(predicted,label='predicted temperature')
plt.legend()
plt.show()

# %%
df_res
# Out:
#        actual  predicted       err
# 0    2.586957   0.002734  2.584223
# 1   -1.388889  -0.110326 -1.278563
# 2    1.588889   0.648648  0.940241
# 3   -0.311111   0.493548 -0.804659
# 4    0.929293   0.550071  0.379222
# ..        ...        ...       ...
# 108  1.000000   0.119651  0.880349
# 109 -0.250000   0.006643 -0.256643
# 110 -1.350000   0.103786 -1.453786
# 111 -0.025000   0.381518 -0.406518
# 112 -0.875000   0.466197 -1.341197
#
# [113 rows x 3 columns]

# %%
df_res.err.plot()
# Out:
# <AxesSubplot:>

# %%
df_res.err.describe()
# Out:
# count    113.000000
# mean       0.003526
# std        1.745464
# min       -5.376131
# 25%       -1.131324
# 50%        0.152716
# 75%        0.991521
# max        3.827306
# Name: err, dtype: float64

# %%
df_res.err.hist()
# Out:
# <AxesSubplot:>

# %%
df_res.err.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from statsmodels.graphics.gofplots import qqplot
qqplot(df_res.err)

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df_res.err)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
# LJung-Box test
import statsmodels.api as sm
pvalue = sm.stats.acorr_ljungbox(m1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model
